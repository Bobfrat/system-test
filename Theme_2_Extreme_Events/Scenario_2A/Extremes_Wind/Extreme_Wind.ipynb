# %% [markdown]
# ># IOOS System Test: [Extreme Events Theme:](https://github.com/ioos/system-test/wiki/Development-of-Test-Themes#theme-2-extreme-events) Coastal Inundation

# %% [markdown]
# ### Questions:
# 1. Can we discover and access long time series wind data from observed datasets?
# 2. Can we estimate the return period of a given wind speed by doing an extreme value analysis of the long term wind data?

# %% [markdown]
# ### Methodology:
# * Define temporal and spatial bounds of interest
# * Define standard names of variable of interest to search for in data sets
# * Search for available service endpoints in the NGDC CSW catalog meeting search criteria
# * Extract OPeNDAP data endpoints from model datasets and SOS endpoints from station observation datasets
# * Obtain long term observation data sets from a station within bounding box (10+ years)
# * Define a new temporal range to search for a particular event (Hurricane Sandy)
# * Using DAP (model) endpoints find all available model data sets in the bounding box, for the specified time range, and extract a model grid cell closest to the observation station
# * Show observation stations and model grid points on a map (red marker for model grid points)
# * Find the maximum wind speed during the event.
# * Perform return period analysis on the long time series observation data and see where the modeled data falls

# %% [markdown]
# #### import required libraries

# %%
import os
from datetime import datetime, timedelta
from io import BytesIO

import uuid
import folium
import json

import matplotlib.pyplot as plt
from owslib.csw import CatalogueServiceWeb
from owslib import fes

from scipy.stats import genextreme
import numpy as np
import pandas as pd
from pyoos.collectors.ndbc.ndbc_sos import NdbcSos
from pyoos.collectors.coops.coops_sos import CoopsSos

from utilities import (fes_date_filter, service_urls, get_coordinates, insert_progress_bar, update_progress_bar,
                       inline_map, css_styles, gather_station_info, get_ncfiles_catalog, new_axes, set_legend, nearxy)

css_styles()
# Out:
#         <style>
#         .info {
#             background-color: #fcf8e3; border-color: #faebcc;
#                 border-left: 5px solid #8a6d3b; padding: 0.5em; color: #8a6d3b;
#         }
#         .success {
#             background-color: #d9edf7; border-color: #bce8f1;
#                 border-left: 5px solid #31708f; padding: 0.5em; color: #31708f;
#         }
#         .error {
#             background-color: #f2dede; border-color: #ebccd1;
#                 border-left: 5px solid #a94442; padding: 0.5em; color: #a94442;
#         }
#         .warning {
#             background-color: #fcf8e3; border-color: #faebcc;
#                 border-left: 5px solid #8a6d3b; padding: 0.5em; color: #8a6d3b;
#         }
#         </style>

# %%
bounding_box_type = "box"

# Bounding Box [lon_min, lat_min, lon_max, lat_max]
area = {'Hawaii': [-160.0, 18.0, -154., 23.0],
        'Gulf of Maine': [-72.0, 41.0, -69.0, 43.0],
        'New York harbor region': [-75., 39., -71., 41.5],
        'Puerto Rico': [-70, 14, -60, 22],
        'East Coast': [-77, 36, -73, 38],
        'North West': [-130, 38, -121, 50],
        'Gulf of Mexico': [-92, 28, -84, 31],
        'Arctic': [-179, 63, -140, 80],
        'North East': [-74, 40, -69, 42],
        'Virginia Beach': [-76, 34, -74, 38],
        'San Diego': [-121, 32, -115, 34]}

bounding_box = area['San Diego']

# Temporal range.
jd_now = datetime.utcnow()
jd_start,  jd_stop = jd_now - timedelta(days=(365*20)), jd_now

start_date = jd_start.strftime('%Y-%m-%d %H:00')
stop_date = jd_stop.strftime('%Y-%m-%d %H:00')

jd_start = datetime.strptime(start_date, '%Y-%m-%d %H:%M')
jd_stop = datetime.strptime(stop_date, '%Y-%m-%d %H:%M')

print('%s to %s ' % (start_date, stop_date))
# Out:
# 1994-12-24 21:00 to 2014-12-19 21:00

# %% [markdown]
# #### Specify data names of interest to search on

# %%
# Put the names in a dict for ease of access.
data_dict = {}
sos_name = 'Winds'
data_dict['winds'] = {
                 "u_names":['eastward_wind', 
                            'u-component_of_wind', 
                            'u_component_of_wind', 
                            'u_component_of_wind_height_above_ground', 
                            'u-component_of_wind_height_above_ground', 
                            'ugrd10m', 
                            'wind'], 
                 "v_names":['northward_wind', 
                            'v-component_of_wind', 
                            'v-component_of_wind_height_above_ground', 
                            'vgrd10m', 
                            'wind'],
                 "sos_name":['winds']}

# %% [markdown]
# #### Define CSW endpoint

# %%
endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'  # NGDC Geoportal.
csw = CatalogueServiceWeb(endpoint, timeout=60)

# %% [markdown]
# #### Search the catologue using the FES filters

# %%
# Convert User Input into FES filters.
start, stop = fes_date_filter(start_date, stop_date)
bbox = fes.BBox(bounding_box)

# Use the search name to create search filter.
kw = dict(propertyname='apiso:AnyText', 
          escapeChar='\\',
          wildCard='*', 
          singleChar='?')

or_filt = fes.Or([fes.PropertyIsLike(literal='*%s*' % val, **kw) 
                  for val in data_dict['winds']['u_names']])

val = 'Averages'
not_filt = fes.Not([fes.PropertyIsLike(literal=('*%s*' % val), **kw)])

filter_list = [fes.And([bbox, start, stop, or_filt, not_filt])]
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')
print("%s csw records found" % len(csw.records))
# Out:
# 366 csw records found

# %% [markdown]
# #### DAP endpoints

# %%
dap_urls = service_urls(csw.records)
# Remove duplicates and organize.
dap_urls = sorted(set(dap_urls))
print("Total DAP: %s" % len(dap_urls))
print("\n".join(dap_urls[:]))
# Out:
# Total DAP: 349
# http://oos.soest.hawaii.edu/thredds/dodsC/hioos/model/atm/ncep_global/NCEP_Global_Atmospheric_Model_best.ncd
# http://oos.soest.hawaii.edu/thredds/dodsC/hioos/model/wav/ww3/WaveWatch_III_Global_Wave_Model_best.ncd
# http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Daily.nc
# http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Monthly.nc
# http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_V3_scat_wind_speed_Weekly.nc
# http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_scat_wind_speed_Daily.nc
# http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_scat_wind_speed_Monthly.nc
# http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_scat_wind_speed_Trimonthly.nc
# http://thredds.axiomalaska.com/thredds/dodsC/Aquarius_scat_wind_speed_Weekly.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_3KM_AGG_AIR_TEMP.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_3KM_AGG_WIND.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_10M_WIND.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_2M_AIR_TEMP.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_AGG_AIR_TEMP.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_AGG_WIND.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_CLD_BASE.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_GRND_SEA_TEMP.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_IR_FLUX.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_PRES_MSL.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_RLTV_HUM.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_SOL_RAD.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_TTL_PRCP.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_4KM_VISIB.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_MBAY_3KM_AIR_TEMP.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_MBAY_3KM_GRND_SEA_TEMP.nc
# http://thredds.axiomalaska.com/thredds/dodsC/COAMPS_MBAY_3KM_WIND_10M.nc
# http://thredds.axiomalaska.com/thredds/dodsC/MAURER.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d10.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d13.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d14.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_d15.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/028p1/028p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d13.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d17.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d18.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_d19.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/029p1/029p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/036p1/036p1_d32.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d10.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d13.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d14.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d15.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_d16.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/043p1/043p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d10.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d13.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d14.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d15.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d16.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d17.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_d18.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/045p1/045p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d10.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d13.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d14.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d15.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d16.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d17.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d18.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d19.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d20.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d21.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_d22.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/067p1/067p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/071p1/071p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/071p1/071p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/071p1/071p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/071p1/071p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/071p1/071p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/071p1/071p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/071p1/071p1_d17.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/071p1/071p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/076p1/076p1_d26.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/076p1/076p1_d27.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d10.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d13.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d14.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_d15.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/091p1/091p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d10.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d13.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d14.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d15.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d16.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d17.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d18.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_d19.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/092p1/092p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d16.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d17.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d19.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d20.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d21.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d22.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d23.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d24.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d25.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d26.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d27.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d28.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d29.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d30.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d31.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d32.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d33.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d34.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d35.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d36.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d37.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d38.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d39.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d40.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_d41.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/093p1/093p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/094p1/094p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/094p1/094p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/094p1/094p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/094p1/094p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/094p1/094p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/094p1/094p1_d10.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/094p1/094p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/094p1/094p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/094p1/094p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/095p1/095p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/095p1/095p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/095p1/095p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/095p1/095p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/095p1/095p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/095p1/095p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/095p1/095p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/095p1/095p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d10.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/096p1/096p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/098p1/098p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d10.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_d13.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/100p1/100p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/101p1/101p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/101p1/101p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/101p1/101p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/101p1/101p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/102p1/102p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/102p1/102p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/102p1/102p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/102p1/102p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/104p1/104p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/104p1/104p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/105p1/105p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/105p1/105p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/111p1/111p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/111p1/111p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/111p1/111p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/111p1/111p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/111p1/111p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/113p1/113p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/113p1/113p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/113p1/113p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/114p1/114p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/114p1/114p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/114p1/114p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/114p1/114p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/114p1/114p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/115p1/115p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/115p1/115p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/115p1/115p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/116p1/116p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/116p1/116p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/116p1/116p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/117p1/117p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/117p1/117p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/118p1/118p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/122p1/122p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/122p1/122p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/123p1/123p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/123p1/123p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/124p1/124p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/124p1/124p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/125p1/125p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/125p1/125p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/126p1/126p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/128p1/128p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/130p1/130p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/133p1/133p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/133p1/133p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/139p1/139p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/139p1/139p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/139p1/139p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/139p1/139p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/141p1/141p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/141p1/141p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d13.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_d14.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/142p1/142p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/155p1/155p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/155p1/155p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/155p1/155p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/155p1/155p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/155p1/155p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/155p1/155p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/156p1/156p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/157p1/157p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/157p1/157p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/161p1/161p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/161p1/161p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/161p1/161p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/161p1/161p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/162p1/162p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/162p1/162p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/166p1/166p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/167p1/167p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/167p1/167p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/167p1/167p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/167p1/167p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/168p1/168p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/172p1/172p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/172p1/172p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/172p1/172p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/174p1/174p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/175p1/175p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/175p1/175p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/175p1/175p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/175p1/175p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_combo_tmp.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/179p1/179p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/182p1/182p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/182p1/182p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/185p1/185p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d02.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d03.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d04.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d05.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d06.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d07.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d08.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d09.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d10.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d11.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_d12.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/191p1/191p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/195p1/195p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/201p1/201p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/201p1/201p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_d01.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/203p1/203p1_historic.nc
# http://thredds.cdip.ucsd.edu/thredds/dodsC/cdip/archive/204p1/204p1_d01.nc

# %% [markdown]
# #### SOS endpoints

# %%
sos_urls = service_urls(csw.records, service='sos:url')
# Remove duplicates and organize.
sos_urls = sorted(set(sos_urls))
print("Total SOS: %s" % len(sos_urls))
print("\n".join(sos_urls[:]))
# Out:
# Total SOS: 325
# http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&request=GetCapabilities
# http://sdf.ndbc.noaa.gov/sos/server.php?service=SOS&request=GetCapabilities&acceptVersions=1.0.0
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d10.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d14.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_d15.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/028p1/028p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_d17.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_d18.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_d19.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/029p1/029p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/036p1/036p1_d32.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d10.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d14.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d15.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_d16.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/043p1/043p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d10.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d14.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d15.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d16.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d17.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_d18.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/045p1/045p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d10.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d14.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d15.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d16.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d17.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d18.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d19.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d20.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d21.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_d22.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/067p1/067p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/071p1/071p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/071p1/071p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/071p1/071p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/071p1/071p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/071p1/071p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/071p1/071p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/071p1/071p1_d17.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/071p1/071p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/076p1/076p1_d26.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/076p1/076p1_d27.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d10.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d14.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_d15.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/091p1/091p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d10.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d14.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d15.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d16.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d17.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d18.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_d19.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/092p1/092p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d16.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d17.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d19.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d20.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d21.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d22.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d23.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d24.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d25.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d26.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d27.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d28.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d29.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d30.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d31.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d32.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d33.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d34.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d35.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d36.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d37.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d38.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d39.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d40.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_d41.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/093p1/093p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/094p1/094p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/094p1/094p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/094p1/094p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/094p1/094p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/094p1/094p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/094p1/094p1_d10.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/094p1/094p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/094p1/094p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/094p1/094p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/095p1/095p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/095p1/095p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/095p1/095p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/095p1/095p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/095p1/095p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/095p1/095p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/095p1/095p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/095p1/095p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d10.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/096p1/096p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/098p1/098p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/098p1/098p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/098p1/098p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/098p1/098p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d10.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/100p1/100p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/101p1/101p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/101p1/101p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/101p1/101p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/101p1/101p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/102p1/102p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/102p1/102p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/102p1/102p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/102p1/102p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/104p1/104p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/104p1/104p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/105p1/105p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/105p1/105p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/111p1/111p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/111p1/111p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/111p1/111p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/111p1/111p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/111p1/111p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/113p1/113p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/113p1/113p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/113p1/113p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/114p1/114p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/114p1/114p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/114p1/114p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/114p1/114p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/114p1/114p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/115p1/115p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/115p1/115p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/115p1/115p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/116p1/116p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/116p1/116p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/116p1/116p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/117p1/117p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/117p1/117p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/118p1/118p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/122p1/122p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/122p1/122p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/123p1/123p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/123p1/123p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/124p1/124p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/124p1/124p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/125p1/125p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/125p1/125p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/126p1/126p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/128p1/128p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/130p1/130p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/133p1/133p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/133p1/133p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/139p1/139p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/139p1/139p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/139p1/139p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/139p1/139p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/141p1/141p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/141p1/141p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/142p1/142p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/142p1/142p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/142p1/142p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/142p1/142p1_d13.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/142p1/142p1_d14.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/142p1/142p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/155p1/155p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/155p1/155p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/155p1/155p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/155p1/155p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/155p1/155p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/155p1/155p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/156p1/156p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/156p1/156p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/156p1/156p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/156p1/156p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/156p1/156p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/157p1/157p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/157p1/157p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/161p1/161p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/161p1/161p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/161p1/161p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/161p1/161p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/162p1/162p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/162p1/162p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/166p1/166p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/167p1/167p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/167p1/167p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/167p1/167p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/167p1/167p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/168p1/168p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/172p1/172p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/172p1/172p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/172p1/172p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/174p1/174p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/175p1/175p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/175p1/175p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/175p1/175p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/175p1/175p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/179p1/179p1_combo_tmp.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/179p1/179p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/179p1/179p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/179p1/179p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/179p1/179p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/182p1/182p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/182p1/182p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/185p1/185p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/185p1/185p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/185p1/185p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d02.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d03.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d04.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d05.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d06.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d07.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d08.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d09.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d10.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d11.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_d12.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/191p1/191p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/195p1/195p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/201p1/201p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/201p1/201p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/203p1/203p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/203p1/203p1_historic.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://thredds.cdip.ucsd.edu/thredds/sos/cdip/archive/204p1/204p1_d01.nc?service=SOS&version=1.0.0&request=GetCapabilities
# http://www.weatherflow.com/sos.pl?service=SOS&request=GetCapabilities

# %% [markdown]
# #### Update SOS time-date

# %%
start_time = datetime.strptime(start_date, '%Y-%m-%d %H:%M')
end_time = datetime.strptime(stop_date, '%Y-%m-%d %H:%M')
iso_start = start_time.strftime('%Y-%m-%dT%H:%M:%SZ')
iso_end = end_time.strftime('%Y-%m-%dT%H:%M:%SZ')

# %% [markdown]
# <div class="success"><strong>Get list of stations</strong>
# - we get a list of the available stations from NOAA and COOPS</div>

# %% [markdown]
# #### Initialize Station Data List

# %%
st_list = {}

# %% [markdown]
# #### Get CO-OPS Station Data

# %%
coops_collector = CoopsSos()
# coops_collector.variables = data_dict["winds"]["sos_name"]
coops_collector.server.identification.title
# Don't specify start and end date in the filter and the most recent observation will be returned
coops_collector.filter(bbox=bounding_box, variables=data_dict["winds"]["sos_name"])

response = coops_collector.raw(responseFormat="text/csv")

obs_loc_df = pd.read_csv(BytesIO(response.encode('utf-8')),
                         parse_dates=True,
                         index_col='date_time')

# Save the station info in a larger global dict
st_list = gather_station_info(obs_loc_df, st_list, "coops")

# Now let's specify start and end times
coops_collector.start_time = start_time
coops_collector.end_time = end_time

ofrs = coops_collector.server.offerings

# Print the first 5 rows of the DataFrame
obs_loc_df.head()
# Out:
#                                                    station_id  \
# date_time
# 2014-12-19 21:18:00  urn:ioos:station:NOAA.NOS.CO-OPS:9410230
# 2014-12-19 21:23:00  urn:ioos:station:NOAA.NOS.CO-OPS:9410647
# 2014-12-19 21:24:00  urn:ioos:station:NOAA.NOS.CO-OPS:9410665
# 2014-12-19 21:22:00  urn:ioos:station:NOAA.NOS.CO-OPS:9410666
# 2014-12-19 21:24:00  urn:ioos:station:NOAA.NOS.CO-OPS:9410670
#
#                                                       sensor_id  \
# date_time
# 2014-12-19 21:18:00  urn:ioos:sensor:NOAA.NOS.CO-OPS:9410230:C1
# 2014-12-19 21:23:00  urn:ioos:sensor:NOAA.NOS.CO-OPS:9410647:C1
# 2014-12-19 21:24:00  urn:ioos:sensor:NOAA.NOS.CO-OPS:9410665:C1
# 2014-12-19 21:22:00  urn:ioos:sensor:NOAA.NOS.CO-OPS:9410666:C1
# 2014-12-19 21:24:00  urn:ioos:sensor:NOAA.NOS.CO-OPS:9410670:C1
#
#                      latitude (degree)  longitude (degree)  \
# date_time
# 2014-12-19 21:18:00            32.8667           -117.2580
# 2014-12-19 21:23:00            33.7158           -118.2461
# 2014-12-19 21:24:00            33.7330           -118.1857
# 2014-12-19 21:22:00            33.7352           -118.2413
# 2014-12-19 21:24:00            33.7483           -118.2680
#
#                      wind_from_direction (degree)  wind_speed (m/s)  \
# date_time
# 2014-12-19 21:18:00                           299               4.0
# 2014-12-19 21:23:00                           244               5.8
# 2014-12-19 21:24:00                           247               6.1
# 2014-12-19 21:22:00                           265               3.9
# 2014-12-19 21:24:00                           293               3.7
#
#                      wind_speed_of_gust (m/s)
# date_time
# 2014-12-19 21:18:00                       4.5
# 2014-12-19 21:23:00                       7.0
# 2014-12-19 21:24:00                       7.1
# 2014-12-19 21:22:00                       4.1
# 2014-12-19 21:24:00                       4.5

# %% [markdown]
# #### Get NDBC Station Data

# %%
ndbc_collector = NdbcSos()
ndbc_collector.variables = data_dict["winds"]["sos_name"]
ndbc_collector.server.identification.title
# Don't specify start and end date in the filter and the most recent observation will be returned
ndbc_collector.filter(bbox=bounding_box,
                 variables=data_dict["winds"]["sos_name"])

response = ndbc_collector.raw(responseFormat="text/csv")
obs_loc_df = pd.read_csv(BytesIO(response.encode('utf-8')),
                         parse_dates=True,
                         index_col='date_time')

# Save the station info in a larger global dict
st_list = gather_station_info(obs_loc_df, st_list, "ndbc")

# Now let's specify start and end times
ndbc_collector.start_time = start_time
ndbc_collector.end_time = end_time

ofrs = ndbc_collector.server.offerings

# Print the first 5 rows of the DataFrame
obs_loc_df.head()
# Out:
#                                      station_id  \
# date_time
# 2014-12-19 20:50:00  urn:ioos:station:wmo:46025
# 2014-12-19 20:50:00  urn:ioos:station:wmo:46047
# 2014-12-19 20:50:00  urn:ioos:station:wmo:46069
# 2014-12-19 20:50:00  urn:ioos:station:wmo:46086
# 2014-12-19 20:24:00  urn:ioos:station:wmo:ljpc1
#
#                                                   sensor_id  \
# date_time
# 2014-12-19 20:50:00  urn:ioos:sensor:wmo:46025::anemometer1
# 2014-12-19 20:50:00  urn:ioos:sensor:wmo:46047::anemometer1
# 2014-12-19 20:50:00  urn:ioos:sensor:wmo:46069::anemometer1
# 2014-12-19 20:50:00  urn:ioos:sensor:wmo:46086::anemometer1
# 2014-12-19 20:24:00  urn:ioos:sensor:wmo:ljpc1::anemometer1
#
#                      latitude (degree)  longitude (degree)  depth (m)  \
# date_time
# 2014-12-19 20:50:00             33.740            -119.060       -5.0
# 2014-12-19 20:50:00             32.433            -119.533       -5.0
# 2014-12-19 20:50:00             33.650            -120.200       -5.0
# 2014-12-19 20:50:00             32.500            -118.000       -5.0
# 2014-12-19 20:24:00             32.867            -117.257      -20.2
#
#                      wind_from_direction (degree)  wind_speed (m/s)  \
# date_time
# 2014-12-19 20:50:00                           310               3.0
# 2014-12-19 20:50:00                           320               5.0
# 2014-12-19 20:50:00                           NaN               0.0
# 2014-12-19 20:50:00                           360               1.0
# 2014-12-19 20:24:00                            90               2.1
#
#                      wind_speed_of_gust (m/s)  upward_air_velocity (m/s)
# date_time
# 2014-12-19 20:50:00                       4.0                        NaN
# 2014-12-19 20:50:00                       7.0                        NaN
# 2014-12-19 20:50:00                       1.0                        NaN
# 2014-12-19 20:50:00                       2.0                        NaN
# 2014-12-19 20:24:00                       3.6                        NaN

# %% [markdown]
# ### Get historical data

# %% [markdown]
# <div class="error">
# <strong>Large Temporal Requests Need To Be Broken Down</strong> -
# When requesting a large temporal range outside the SOS limit, the sos
# request needs to be broken down.  See issues in
# [ioos](https://github.com/ioos/system-test/issues/81),
# [ioos](https://github.com/ioos/system-test/issues/101),
# [ioos](https://github.com/ioos/system-test/issues/116)
# and
# [pyoos](https://github.com/ioos/pyoos/issues/35).  Unfortunately winds
# is not available via DAP
# ([ioos](https://github.com/ioos/system-test/issues/116))</div>

# %% [markdown]
# <div class="error"><strong>Processing long time series</strong> -
# The CO-OPS Server responds really slow (> 30 secs, for what should be
# a 5 sec request) to multiple requests, so getting long time series
# data is almost impossible.</div>

# %% [markdown]
# <div class="info">
# <strong>Use NDBC DAP endpoints to get time-series data</strong> -
# The DAP server for met data is available for NDBC, we use that
# to get long time series data.</div>

# %%
divid = insert_progress_bar(title='Please wait...', color='red')
# Used to define the number of days allowable by the service.
coops_point_max_days = ndbc_point_max_days = 30
print("start & end dates: %s, %s\n" % (jd_start, jd_stop))
num_stations = len(st_list.keys())
count = 0
for station in st_list.keys():
    count += 1
    # Set it so we can use it later.
    st = station.split(":")[-1]
    print('[%s]: %s' % (st_list[station]['source'], st))

    if st_list[station]['source'] == 'coops':
        # Coops fails for large requests.
        master_df = pd.DataFrame()
    elif st_list[station]['source'] == 'ndbc':
        # Use the dap catalog to get the data.
        master_df = get_ncfiles_catalog(station, jd_start, jd_stop)

    if not master_df.empty:
        st_list[station]['hasObsData'] = True
    else:
        st_list[station]['hasObsData'] = False

    st_list[station]['obsData'] = master_df
    
    percent_complete = (float(count)/float(num_stations)) * 100
    update_progress_bar(divid, percent_complete)
# Out:
# Please wait...
#         <div style="border: 1px solid black; width:500px">
#           <div id="70201ac2-bc51-40f3-8d5b-1d683128ea4f" style="background-color:red; width:0%">&nbsp;</div>
#         </div>
# start & end dates: 1994-12-24 21:00:00, 2014-12-19 21:00:00
#
# [ndbc]: 46086
# [ndbc]: 46025
# [ndbc]: ljpc1
# [ndbc]: 46069
# [coops]: 9410665
# [coops]: 9410690
# [coops]: 9410670
# [coops]: 9410666
# [ndbc]: 46047
# [coops]: 9410647
# [coops]: 9410691
# [coops]: 9410230
# [coops]: 9410692

# %% [markdown]
# ### Plot the station data

# %%
for station in st_list.keys():
    if st_list[station]['hasObsData']:
        df = st_list[station]['obsData']
        fig, axes = plt.subplots(1, 1, figsize=(18, 4))
        df['wind_speed (m/s)'].plot(title='Station:' + station, legend=True, color='b')

# %% [markdown]
# #### Plot wind rose

# %%
# Remove any existing plots...
filelist = [f for f in os.listdir("./images") if f.endswith(".png")]
for f in filelist:
    os.remove("./images/{}".format(f))

# Do work...
for station in st_list.keys():    
    if st_list[station]['hasObsData']:
        df = st_list[station]['obsData']
        try:
            # A stacked histogram with normed (displayed in percent) results.
            ax = new_axes()  # Wind rose polar axes
            ax.set_title("Station " + station.split(":")[-1] +
                         "\nstacked histogram with normed (displayed in %)")
            wind_speed = df['wind_speed (m/s)'].values
            wind_direction = df['wind_from_direction (degree)'].values
            ax.bar(wind_direction, wind_speed, normed=True, opening=0.8, edgecolor='white')
            set_legend(ax, 'Wind Speed (m/s)')

            fig = plt.gcf()
            fig.set_size_inches(8, 8)
            fname = './images/%s.png' % station.split(":")[-1]
            fig.savefig(fname, dpi=100)
        except Exception as e:
            print("Error when plotting %s" % e)

# %% [markdown]
# #### Define a couple plotting functions

# %%
def plot_probability_density(annual_max, station_id):
    mle = genextreme.fit(sorted(annual_max), 0)
    mu = mle[1]
    sigma = mle[2]
    xi = mle[0]
    min_x = min(annual_max)-0.5
    max_x = max(annual_max)+0.5
    x = np.linspace(min_x, max_x, num=100)
    y = [genextreme.pdf(z, xi, loc=mu, scale=sigma) for z in x]

    fig = plt.figure(figsize=(12,6))
    axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
    xlabel = (station_id + " - Annual Max Wind Speed (m/s)")
    axes.set_title("Probability Density & Normalized Histogram")
    axes.set_xlabel(xlabel)
    axes.plot(x, y, color='Red')
    axes.hist(annual_max, bins=arange(min_x, max_x, abs((max_x-min_x)/10)), normed=1, color='Yellow')

# %%
def plot_return_values(annual_max, station_id):
    fig, axes = plt.subplots(figsize=(20,6))
    T=np.r_[1:500]
    mle = genextreme.fit(sorted(annual_max), 0)
    mu = mle[1]
    sigma = mle[2]
    xi = mle[0]
#     print "The mean, sigma, and shape parameters are %s, %s, and %s, resp." % (mu, sigma, xi)
    sT = genextreme.isf(1./T, 0, mu, sigma)
    axes.semilogx(T, sT, 'r'), hold
    N=np.r_[1:len(annual_max)+1]; 
    Nmax=max(N);
    axes.plot(Nmax/N, sorted(annual_max)[::-1], 'bo')
    title = station_id
    axes.set_title(title)
    axes.set_xlabel('Return Period (yrs)')
    axes.set_ylabel('Wind Speed (m/s)') 
    axes.grid(True)

# %% [markdown]
# #### Get the Annual Maximums and plot Probability Density

# %%
for station in st_list.keys():    
    annual_max = []
    if st_list[station]['hasObsData']:
        df = st_list[station]['obsData']
        grouped = df.groupby(lambda x: x.year)
        for year, group in grouped:
            # This is where you could check that there is enough data in the year
            # For example, if there is only
            annual_max.append(group['wind_speed (m/s)'].max())
        print  "Station {0} has {1} years of data".format(station.split(":")[-1], len(annual_max))
        if len(annual_max) > 10:  # Need AT LEAST 10 years of data
            plot_probability_density(annual_max, station.split(":")[-1])
            plot_return_values(annual_max, station.split(":")[-1])
    st_list[station]['annual_max'] = annual_max
# Out:
# Station 46086 has 12 years of data
# Station 46025 has 21 years of data
# Station ljpc1 has 8 years of data
# Station 46069 has 12 years of data
# Station 46047 has 17 years of data

# %% [markdown]
# ##Get WIS Hindcast data
# ###All of the WIS stations annual maximum data was downloaded and saved to a json file (WIS_extremes.txt)
# The Wave Information Studies (WIS) is a US Army Corps of Engineers (USACE) sponsored project that generates consistent, hourly, long-term (20+ years) wave climatologies along all US coastlines, including the Great Lakes and US island territories. The WIS program originated in the Great Lakes in the mid 1970’s and migrated to the Atlantic, Gulf of Mexico and Pacific Oceans.

# %%
with open("./WIS_stations.txt") as json_file:
    location_data = json.load(json_file)
    
wis_lats = []
wis_lons = []
wis_stations = []
for station in location_data:
    wis_lats.append(location_data[station]['lat'])
    wis_lons.append(location_data[station]['lon'])
    wis_stations.append(station)

station_lats = []
station_lons = []
for station in st_list.keys():    
    if st_list[station]['hasObsData']:
        station_lats.append(st_list[station]['lat'])
        station_lons.append(st_list[station]['lon'])
        
ind, dd = nearxy(wis_lons, wis_lats, station_lons, station_lats)       

# Now get read the wis data
with open("./WIS_extremes.txt") as extremes_file:
    wis_extremes = json.load(extremes_file)

# Get the extremes from the closest station
wis_station_id = wis_stations[ind[0]]
wis_lat = wis_lats[ind[0]]
wis_lon = wis_lons[ind[0]]

wis_maximums = []
wis_directions = []
for year in wis_extremes[wis_station_id].keys():
    wis_maximums.append(wis_extremes[wis_station_id][year]['ws_at_max'])
    wis_directions.append(wis_extremes[wis_station_id][year]['wdir_at_max'])

# %% [markdown]
# #### Return Value Plot

# %%
plot_return_values(wis_maximums, 'WIS ' + str(wis_station_id))

# %% [markdown]
# ### Create interactive map with wind rose images on icons

# %%
station = st_list[st_list.keys()[0]]
m = folium.Map(location=[station["lat"], station["lon"]], zoom_start=4)
m.line(get_coordinates(bounding_box, bounding_box_type),
       line_color='#FF0000', line_weight=5)

for st in st_list:
    hasObs = st_list[st]['hasObsData']
    if hasObs:
        fname = './images/%s.png' % st.split(":")[-1]
        if os.path.isfile(fname):
            popup = ('Obs Location:<br>%s<br><img border=120 src="'
                     './images/%s.png" width="242" height="242">' %
                     (st, st.split(":")[-1]))
            m.simple_marker([st_list[st]["lat"], st_list[st]["lon"]],
                            popup=popup,
                            marker_color="green",
                            marker_icon="ok")
        else:
            popup = 'Obs Location:<br>%s' % st
            m.simple_marker([st_list[st]["lat"], st_list[st]["lon"]],
                            popup=popup,
                            marker_color="green",
                            marker_icon="ok")
    else:
        popup = 'Obs Location:<br>%s' % st
        m.simple_marker([st_list[st]["lat"], st_list[st]["lon"]],
                        popup=popup,
                        marker_color="red",
                        marker_icon="remove")
        
# Add WIS lat/lon
m.simple_marker([wis_lat, wis_lon],
                    popup='WIS Station' + str(wis_station_id),
                    marker_color="purple",
                    marker_icon="ok")
inline_map(m)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.7.3/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;http://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_e1b80834e2a248f797816fc1cb806182&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_e1b80834e2a248f797816fc1cb806182', {
#                                        center:[32.5, -118.0],
#                                        zoom: 4,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'green',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([32.5,
# 							-118.0],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;Obs Location:<br>urn:ioos:station:wmo:46086<br><img border=120 src=\&quot;./images/46086.png\&quot; width=\&quot;242\&quot; height=\&quot;242\&quot;>&quot;);
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'green',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([33.74,
# 							-119.06],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;Obs Location:<br>urn:ioos:station:wmo:46025<br><img border=120 src=\&quot;./images/46025.png\&quot; width=\&quot;242\&quot; height=\&quot;242\&quot;>&quot;);
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'green',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([32.867,
# 							-117.257],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;Obs Location:<br>urn:ioos:station:wmo:ljpc1<br><img border=120 src=\&quot;./images/ljpc1.png\&quot; width=\&quot;242\&quot; height=\&quot;242\&quot;>&quot;);
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'green',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([33.65,
# 							-120.2],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;Obs Location:<br>urn:ioos:station:wmo:46069<br><img border=120 src=\&quot;./images/46069.png\&quot; width=\&quot;242\&quot; height=\&quot;242\&quot;>&quot;);
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'remove',markerColor: 'red',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([33.733,
# 							-118.1857],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;Obs Location:<br>urn:ioos:station:NOAA.NOS.CO-OPS:9410665&quot;);
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'remove',markerColor: 'red',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([33.7636,
# 							-118.2654],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;Obs Location:<br>urn:ioos:station:NOAA.NOS.CO-OPS:9410690&quot;);
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'remove',markerColor: 'red',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([33.7483,
# 							-118.268],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;Obs Location:<br>urn:ioos:station:NOAA.NOS.CO-OPS:9410670&quot;);
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'remove',markerColor: 'red',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([33.7352,
# 							-118.2413],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;Obs Location:<br>urn:ioos:station:NOAA.NOS.CO-OPS:9410666&quot;);
#       map.addLayer(marker_8)
#
#       var marker_9_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'green',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_9 = L.marker([32.433,
# 							-119.533],
# 							{'icon':marker_9_icon}
# 							);
#       marker_9.bindPopup(&quot;Obs Location:<br>urn:ioos:station:wmo:46047<br><img border=120 src=\&quot;./images/46047.png\&quot; width=\&quot;242\&quot; height=\&quot;242\&quot;>&quot;);
#       map.addLayer(marker_9)
#
#       var marker_10_icon = L.AwesomeMarkers.icon({ icon: 'remove',markerColor: 'red',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_10 = L.marker([33.7158,
# 							-118.2461],
# 							{'icon':marker_10_icon}
# 							);
#       marker_10.bindPopup(&quot;Obs Location:<br>urn:ioos:station:NOAA.NOS.CO-OPS:9410647&quot;);
#       map.addLayer(marker_10)
#
#       var marker_11_icon = L.AwesomeMarkers.icon({ icon: 'remove',markerColor: 'red',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_11 = L.marker([33.7663,
# 							-118.2401],
# 							{'icon':marker_11_icon}
# 							);
#       marker_11.bindPopup(&quot;Obs Location:<br>urn:ioos:station:NOAA.NOS.CO-OPS:9410691&quot;);
#       map.addLayer(marker_11)
#
#       var marker_12_icon = L.AwesomeMarkers.icon({ icon: 'remove',markerColor: 'red',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker

# %% [markdown]
# ### Conclusions
#
# * It is possible to discover and access long time series wind data from observed datasets. Some endpoints make it easier than others. Co-ops stations limit data requests to 31 days, making it difficult to get long time series data, but NDBC has an OpenDap Server that makes it much easier.
#
# * The wind speeds and directions were used to create wind rose plots and return value analysis plots. The amount of data available depends on the location. There are long data records (> 10 yrs) in the mid Atlantic and parts of the West Coast.
